# %%
## 불(booL) 자료형

a = True
b = False 

type(a)
type(b)
# Out:
# bool

# %%
# 같다
1 == 1

print(2 > 1)
print(1 > 2)
print(2 >= 2)
print(2 <= 1)
print(1 != 2) # 같지 않다
# Out:
# True
# False
# True
# False
# True

# %%
print(bool(1))
print(bool(0))
print(bool(""))
print(bool("python"))
print(bool([]))
print(bool([1, 2]))
# Out:
# True
# False
# False
# True
# False
# True

# %%
# and 연산자
print(True and True)
print(True and False)
print(False and False)
# Out:
# True
# False
# False

# %%
# OR 연산자
print(True or True)
print(True or False)
print(False or False)
# Out:
# True
# True
# False

# %%
# 변수 

a = 15

print(a >= 10 and a < 20)
# Out:
# True
