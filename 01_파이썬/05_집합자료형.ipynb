# %%
## 집합자료형 생성

s1 = set([1, 2, 3])
s1
# Out:
# {1, 2, 3}

# %%
s1 = set([1, 2, 3])
l1 = list(s1)
l1
# Out:
# [1, 2, 3]

# %%
## 교집합, 합집합, 차집합 구하기
s1 = set([1, 2, 3, 4, 5, 6])
s2 = set([4, 5, 6, 7, 8, 9])
s1 & s2
# Out:
# {4, 5, 6}

# %%
s1.intersection(s2)
# Out:
# {4, 5, 6}

# %%
# 합집합 구하기
s1 | s2
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 9}

# %%
s1.union(s2)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 9}

# %%
# 차집합 구하기
s1 - s2
# Out:
# {1, 2, 3}

# %%
s1.difference(s2)
# Out:
# {1, 2, 3}
